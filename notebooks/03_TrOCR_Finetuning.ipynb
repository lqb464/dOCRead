# %% [markdown]
# # 03 — TrOCR Fine-Tuning
#
# **Goal**: Fine-tune the HuggingFace TrOCR (Vision-Encoder-Decoder) model on our synthetic handwritten and printed datasets.

# %%
from transformers import TrOCRProcessor, VisionEncoderDecoderModel
from PIL import Image

# %% [markdown]
# TrOCR replaces the entire CNN-RNN pipeline with a 100% Transformer architecture. It uses a Vision Transformer (ViT) to encode the image and a text Transformer (like RoBERTa or BART) to decode the characters.

# %%
processor = TrOCRProcessor.from_pretrained("microsoft/trocr-base-handwritten")
model = VisionEncoderDecoderModel.from_pretrained("microsoft/trocr-base-handwritten")

# To fine-tune, you would freeze the encoder and train the decoder on custom data:
# for name, param in model.encoder.named_parameters():
#     param.requires_grad = False
